# %%
countries = ['India','USA','Australia',1,1.24]
print(countries)

print("Value at 0 index:", countries[0])

countries[0]='Germany'



hybridlists=['My sem is ',6,'Sem']

print(hybridlists)


for item in hybridlists:
  print(item)

countries = ['India','USA','Australia',1,1.24]


for index, country in enumerate(countries):
  place=str(index)

  print("Index:", place, ", value:", country)

index=countries.index('India')
print("\n index of india is: ",index)


del countries [-1]
print(countries)
# Out:
# ['India', 'USA', 'Australia', 1, 1.24]
# Value at 0 index: India
# ['My sem is ', 6, 'Sem']
# My sem is
# 6
# Sem
# Index: 0 , value: India
# Index: 1 , value: USA
# Index: 2 , value: Australia
# Index: 3 , value: 1
# Index: 4 , value: 1.24
#
#  index of india is:  0
# ['India', 'USA', 'Australia', 1]

# %%
l=[1,2,3,4,4]
for i in l:
  print(i%2)
# Out:
# 1
# 0
# 1
# 0
# 0

# %%
l=[2,4,6,8,10,114]
[i**2 for i in l if i**2>50]
# Out:
# [64, 100, 12996]

# %%
dict ={"sedan": 1500, "suv":2000,"pickup": 2500}
d=[i.lower() for i in dict if dict[i]<5000]
print(d)
# Out:
# ['sedan', 'suv', 'pickup']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=['high' if i>5 else 'low' for i in l]
print(l2)
# Out:
# ['low', 'low', 'low', 'low', 'low', 'high', 'high', 'high', 'high']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=[1 if i>5 else 0 for i in l]
print(l2)
# Out:
# [0, 0, 0, 0, 0, 1, 1, 1, 1]

# %%
[27*x for x in range (1,21) if x**2<=10]
# Out:
# [27, 54, 81]

# %%
[x for x in range(51) if x%2==0 and x%5==0]
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
string = "i love this csit department"
j=[i for i in string if i in ["a","e","i","o","u"]]
print(j)
# Out:
# ['i', 'o', 'e', 'i', 'i', 'e', 'a', 'e']

# %%
l=[1,2,3,4,5,6,7,8,9]
l2=[l.pop(l.index(i)) for i in l if i%2!=0]
print(l2)
# Out:
# [1, 3, 5, 7, 9]

# %%
sentence = 'In 1983 india won the world cup'
words = sentence.split()
result = [number for number in words if not number.isalpha()]
print(result)
# Out:
# ['1983']

# %%
list_a=[1,2,3,4]
list_b=[2,3,4,5]
common=[a for a in list_a if a in list_b]
print(common)
# Out:
# [2, 3, 4]
